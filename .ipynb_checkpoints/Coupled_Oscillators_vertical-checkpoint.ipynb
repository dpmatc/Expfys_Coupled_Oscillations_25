# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %%
m1 = 0.9993
m2 = 0.506
k1 = 230
k2 = 72
M = np.matrix([[m1, 0], [0, m2]])
K = np.matrix([[k1+k2, -k2], [-k2, k2]])

# %%
# Define external forces f1(t), f2(t)
def f1(t): 
    return 0.0             # example: no forcing
def f2(t): 
    return 1.0*np.sin(2*t) # example: sinusoidal forcing

# ODE system
def deriv(t, X):
    x1, x2, x3, x4 = X
    dx1dt = x2
    dx2dt = (f1(t) + k2*(x3 - x1) - k1*x1) / m1
    dx3dt = x4
    dx4dt = (f2(t) - k2*(x3 - x1)) / m2
    return [dx1dt, dx2dt, dx3dt, dx4dt]

# Initial conditions
X0 = [0.0, 0.0, 0.0, 0.0]

# Time span
t_span = (0, 20)
t_eval = np.linspace(*t_span, 2000)

# Solve numerically
sol = solve_ivp(deriv, t_span, X0, t_eval=t_eval, rtol=1e-8, atol=1e-8)

# Extract solutions
t = sol.t
y1, y2 = sol.y[0], sol.y[2]

# Plot results
plt.figure(figsize=(8,4))
plt.plot(t, y1, label='$y_1(t)$')
plt.plot(t, y2, label='$y_2(t)$')
plt.xlabel('Time [s]')
plt.ylabel('Displacement')
plt.legend()
plt.grid(True)
plt.show()
